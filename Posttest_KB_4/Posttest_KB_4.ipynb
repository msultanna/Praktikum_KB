# %%
#IMPORT PACKAGE

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
#RECORD cars.csv

df = pd.read_csv('cars.csv')

# %%
df
# Out:
#       manufacturer_name  model_name transmission   color  odometer_value  \
# 0                Subaru     Outback    automatic  silver          190000
# 1                Subaru     Outback    automatic    blue          290000
# 2                Subaru    Forester    automatic     red          402000
# 3                Subaru     Impreza   mechanical    blue           10000
# 4                Subaru      Legacy    automatic   black          280000
# ...                 ...         ...          ...     ...             ...
# 38526          Chrysler         300    automatic  silver          290000
# 38527          Chrysler  PT Cruiser   mechanical    blue          321000
# 38528          Chrysler         300    automatic    blue          777957
# 38529          Chrysler  PT Cruiser   mechanical   black           20000
# 38530          Chrysler     Voyager    automatic  silver          297729
#
#        year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38531 entries, 0 to 38530
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   manufacturer_name  38531 non-null  object
#  1   model_name         38531 non-null  object
#  2   transmission       38531 non-null  object
#  3   color              38531 non-null  object
#  4   odometer_value     38531 non-null  int64
#  5   year_produced      38531 non-null  int64
#  6   engine_fuel        38531 non-null  object
#  7   engine_has_gas     38531 non-null  bool
#  8   engine_type        38531 non-null  object
#  9   engine_capacity    38521 non-null  float64
#  10  body_type          38531 non-null  object
#  11  has_warranty       38531 non-null  bool
#  12  state              38531 non-null  object
#  13  drivetrain         38531 non-null  object
#  14  price_usd          38531 non-null  float64
#  15  is_exchangeable    38531 non-null  bool
# ...

# %%
df.isna().sum()
# Out:
# manufacturer_name     0
# model_name            0
# transmission          0
# color                 0
# odometer_value        0
# year_produced         0
# engine_fuel           0
# engine_has_gas        0
# engine_type           0
# engine_capacity      10
# body_type             0
# has_warranty          0
# state                 0
# drivetrain            0
# price_usd             0
# is_exchangeable       0
# location_region       0
# number_of_photos      0
# up_counter            0
# feature_0             0
# feature_1             0
# feature_2             0
# feature_3             0
# feature_4             0
# feature_5             0
# feature_6             0
# feature_7             0
# feature_8             0
# feature_9             0
# duration_listed       0
# dtype: int64

# %%
#DATA SPLIT

x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=.3)

# %%
print(f"panjang x_train : {len(x_train)})",
      f"panjang y_test : {len(x_test)}",
      f"panjang y_train : {len(y_train)}",
      f"panjang y_test : {len(y_test)}",
      sep='\n')
# Out:
# panjang x_train : 26971)
# panjang y_test : 11560
# panjang y_train : 26971
# panjang y_test : 11560

# %%
#Data Transformasi

normalisasi_dataset = df.copy()
standarisasi_dataset = df.copy()

# %%
scaler = MinMaxScaler()
normalize_dataset = scaler.fit_transform(normalisasi_dataset[['number_of_photos', 'up_counter', 'odometer_value']])
normalize_dataset = pd.DataFrame(normalize_dataset)
normalize_dataset.rename(columns={0 :'number_of_photos', 1 : 'up_counter', 2 : 'odometer_value'}, inplace=True)
normalize_dataset.head(5)
# Out:
#    number_of_photos  up_counter  odometer_value
# 0          0.094118    0.006452           0.190
# 1          0.129412    0.028495           0.290
# 2          0.035294    0.038172           0.402
# 3          0.094118    0.022043           0.010
# 4          0.152941    0.003226           0.280

# %%
ss = StandardScaler()
Scaled_data = ss.fit_transform(standarisasi_dataset[['number_of_photos', 'up_counter', 'odometer_value']])

# %%
print("Nilai Sebelum Standarisasi :")
print("Standar Deviasi :", np.std(standarisasi_dataset))
# Out:
# Nilai Sebelum Standarisasi :
# Standar Deviasi : odometer_value      136070.610766
# year_produced            8.065626
# engine_has_gas           0.183676
# engine_capacity          0.671169
# has_warranty             0.107318
# price_usd             6428.068602
# is_exchangeable          0.477779
# number_of_photos         6.093138
# up_counter              43.286371
# feature_0                0.419894
# feature_1                0.488373
# feature_2                0.416803
# feature_3                0.446918
# feature_4                0.427973
# feature_5                0.478838
# feature_6                0.376491
# feature_7                0.440658
# feature_8                0.492778
# feature_9                0.493655
# duration_listed        112.825105
# dtype: float64
# ...

# %%
print("Nilai Sesudah Standarisasi :")
print("Standar Deviasi :", np.std(Scaled_data))
# Out:
# Nilai Sesudah Standarisasi :
# Standar Deviasi : 0.9999999999999999

# %%
ss = StandardScaler()
Scaled_data = ss.fit_transform(df[['number_of_photos', 'up_counter', 'odometer_value']])

# %%
print("Nilai Sebelum Standarisasi : ")
print("Standar Deviasi : ", np.std(df))
# Out:
# Nilai Sebelum Standarisasi :
# Standar Deviasi :  odometer_value      136070.610766
# year_produced            8.065626
# engine_has_gas           0.183676
# engine_capacity          0.671169
# has_warranty             0.107318
# price_usd             6428.068602
# is_exchangeable          0.477779
# number_of_photos         6.093138
# up_counter              43.286371
# feature_0                0.419894
# feature_1                0.488373
# feature_2                0.416803
# feature_3                0.446918
# feature_4                0.427973
# feature_5                0.478838
# feature_6                0.376491
# feature_7                0.440658
# feature_8                0.492778
# feature_9                0.493655
# duration_listed        112.825105
# dtype: float64
# ...

# %%
print("Nilai Setelah Standarisasi : ")
print("Standar Deviasi : ", np.std(Scaled_data))
# Out:
# Nilai Setelah Standarisasi :
# Standar Deviasi :  0.9999999999999999

# %%
#Data Cleaning

dataset_ns = df.copy()

# %%
imputer_mean = SimpleImputer(strategy='mean')
imputer_median = SimpleImputer(strategy='median')
imputer_modus = SimpleImputer(strategy='most_frequent')

# %%
#DATA DUPLIKAT

dataset_duplicate = df.copy()

dataset_duplicate.duplicated().sum()
# Out:
# 40

# %%
dataset_duplicate.drop_duplicates(inplace=True)

dataset_duplicate.duplicated().sum()
# Out:
# 0

# %%
#ENCODING

dataset_ordinal = df.copy()
dataset_one_hot = df.copy()

# %%
df['engine_type'].unique()
# Out:
# array(['gasoline', 'diesel', 'electric'], dtype=object)

# %%
#ORDINAL

encoder_ordinal =OrdinalEncoder()

#encoding kan
dataset_ordinal['engine_type'] = encoder_ordinal.fit_transform(dataset_ordinal[['engine_type']]).astype('int64')

#lihat
dataset_ordinal.head()
# Out:
#   manufacturer_name model_name transmission   color  odometer_value  \
# 0            Subaru    Outback    automatic  silver          190000
# 1            Subaru    Outback    automatic    blue          290000
# 2            Subaru   Forester    automatic     red          402000
# 3            Subaru    Impreza   mechanical    blue           10000
# 4            Subaru     Legacy    automatic   black          280000
#
#    year_produced engine_fuel  engine_has_gas  engine_type  engine_capacity  \
# 0           2010    gasoline           False            2              2.5
# 1           2002    gasoline           False            2              3.0
# 2           2001    gasoline           False            2              2.5
# 3           1999    gasoline           False            2              3.0
# 4           2001    gasoline           False            2              2.5
#
#    ... feature_1  feature_2 feature_3 feature_4  feature_5  feature_6  \
# ...
